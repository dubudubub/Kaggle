# %%
#https://www.kaggle.com/code/dhirajkumar612/89-01-bike-rental-prediction/notebook

# %%
#Importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
import statsmodels.api as sm
warnings.filterwarnings("ignore")
#imported different libraries where we will be working with.

# %%
pd.set_option("display.max_rows", 100, "display.max_columns", 100)

# %%
#Importing dataset
df=pd.read_csv('/Users/eunji/Downloads/Kaggle/Bike Rental Prediction/SeoulBikeData.csv', encoding='unicode_escape',parse_dates=[0])

# %%
#Dataset view
df.head(5)
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %%
#Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   datetime64[ns]
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functioning Day            8760 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(4), object(3)
# memory usage: 958.2+ KB

# %%
df=df.astype({'Rented Bike Count':'float','Hour':'object'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   datetime64[ns]
#  1   Rented Bike Count          8760 non-null   float64
#  2   Hour                       8760 non-null   object
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functioning Day            8760 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(4)
# memory usage: 958.2+ KB

# %%
df=df.rename(columns={'Temperature°C)':'Temperature','Humidity(%)':'Humidity','Rainfall(mm)':'Rainfall','Snowfall (cm)':'Snowfall','Wind speed (m/s)':'Wind speed','Visibility (10m)':'Visibility','Solar Radiation (MJ/m2)':'Radiation','Dew point temperature(°C)':'Dew point temperature'})

# %%
#Summary Statistics
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_25289_row0_col0, #T_25289_row0_col1, #T_25289_row0_col2, #T_25289_row0_col3, #T_25289_row0_col4, #T_25289_row0_col5, #T_25289_row0_col6, #T_25289_row0_col7, #T_25289_row0_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_25289_row1_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_25289_row1_col1, #T_25289_row1_col3, #T_25289_row1_col6, #T_25289_row1_col7, #T_25289_row1_col8, #T_25289_row2_col1, #T_25289_row2_col2, #T_25289_row2_col3, #T_25289_row2_col6, #T_25289_row2_col7, #T_25289_row2_col8, #T_25289_row3_col0, #T_25289_row3_col1, #T_25289_row3_col2, #T_25289_row3_col3, #T_25289_row3_col4, #T_25289_row3_col5, #T_25289_row3_col6, #T_25289_row3_col7, #T_25289_row3_col8, #T_25289_row4_col1, #T_25289_row4_col3, #T_25289_row4_col5, #T_25289_row4_col6, #T_25289_row4_col7, #T_25289_row4_col8, #T_25289_row5_col1, #T_25289_row5_col3, #T_25289_row5_col6, #T_25289_row5_col7, #T_25289_row5_col8, #T_25289_row6_col3, #T_25289_row6_col6, #T_25289_row6_col7, #T_25289_row6_col8, #T_25289_row7_col3, #T_25289_row7_col6, #T_25289_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_25289_row1_col2, #T_25289_row1_col5, #T_25289_row2_col5, #T_25289_row4_col2, #T_25289_row5_col2, #T_25289_row5_col5, #T_25289_row6_col1, #T_25289_row6_col5, #T_25289_row7_col1, #T_25289_row7_col5, #T_25289_row7_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_25289_row1_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_25289_row2_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_25289_row2_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_25289_row4_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_25289_row4_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_25289_row5_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_25289_row5_col4 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_25289_row6_col0 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_25289_row6_col2, #T_25289_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_25289_row6_col4, #T_25289_row7_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_25289_row7_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# </style>
# <table id="T_25289">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25289_level0_col0" class="col_heading level0 col0" >Rented Bike Count</th>
#       <th id="T_25289_level0_col1" class="col_heading level0 col1" >Temperature(°C)</th>
#       <th id="T_25289_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_25289_level0_col3" class="col_heading level0 col3" >Wind speed</th>
#       <th id="T_25289_level0_col4" class="col_heading level0 col4" >Visibility</th>
#       <th id="T_25289_level0_col5" class="col_heading level0 col5" >Dew point temperature</th>
#       <th id="T_25289_level0_col6" class="col_heading level0 col6" >Radiation</th>
#       <th id="T_25289_level0_col7" class="col_heading level0 col7" >Rainfall</th>
#       <th id="T_25289_level0_col8" class="col_heading level0 col8" >Snowfall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25289_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_25289_row0_col0" class="data row0 col0" >8760.000000</td>
#       <td id="T_25289_row0_col1" class="data row0 col1" >8760.000000</td>
#       <td id="T_25289_row0_col2" class="data row0 col2" >8760.000000</td>
#       <td id="T_25289_row0_col3" class="data row0 col3" >8760.000000</td>
#       <td id="T_25289_row0_col4" class="data row0 col4" >8760.000000</td>
#       <td id="T_25289_row0_col5" class="data row0 col5" >8760.000000</td>
#       <td id="T_25289_row0_col6" class="data row0 col6" >8760.000000</td>
#       <td id="T_25289_row0_col7" class="data row0 col7" >8760.000000</td>
#       <td id="T_25289_row0_col8" class="data row0 col8" >8760.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25289_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_25289_row1_col0" class="data row1 col0" >704.602055</td>
#       <td id="T_25289_row1_col1" class="data row1 col1" >12.882922</td>
#       <td id="T_25289_row1_col2" class="data row1 col2" >58.226256</td>
#       <td id="T_25289_row1_col3" class="data row1 col3" >1.724909</td>
#       <td id="T_25289_row1_col4" class="data row1 col4" >1436.825799</td>
#       <td id="T_25289_row1_col5" class="data row1 col5" >4.073813</td>
#       <td id="T_25289_row1_col6" class="data row1 col6" >0.569111</td>
#       <td id="T_25289_row1_col7" class="data row1 col7" >0.148687</td>
#       <td id="T_25289_row1_col8" class="data row1 col8" >0.075068</td>
#     </tr>
#     <tr>
#       <th id="T_25289_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_25289_row2_col0" class="data row2 col0" >644.997468</td>
#       <td id="T_25289_row2_col1" class="data row2 col1" >11.944825</td>
#       <td id="T_25289_row2_col2" class="data row2 col2" >20.362413</td>
#       <td id="T_25289_row2_col3" class="data row2 col3" >1.036300</td>
#       <td id="T_25289_row2_col4" class="data row2 col4" >608.298712</td>
#       <td id="T_25289_row2_col5" class="data row2 col5" >13.060369</td>
#       <td id="T_25289_row2_col6" class="data row2 col6" >0.868746</td>
#       <td id="T_25289_row2_col7" class="data row2 col7" >1.128193</td>
#       <td id="T_25289_row2_col8" class="data row2 col8" >0.436746</td>
#     </tr>
#     <tr>
#       <th id="T_25289_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_25289_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_25289_row3_col1" class="data row3 col1" >-17.800000</td>
#       <td id="T_25289_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_25289_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_25289_row3_col4" class="data row3 col4" >27.000000</td>
#       <td id="T_25289_row3_col5" class="data row3 col5" >-30.600000</td>
#       <td id="T_25289_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_25289_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_25289_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25289_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_25289_row4_col0" class="data row4 col0" >191.000000</td>
#       <td id="T_25289_row4_col1" class="data row4 col1" >3.500000</td>
#       <td id="T_25289_row4_col2" class="data row4 col2" >42.000000</td>
#       <td id="T_25289_row4_col3" class="data row4 col3" >0.900000</td>
#       <td id="T_25289_row4_col4" class="data row4 col4" >940.000000</td>
#       <td id="T_25289_row4_col5" class="data row4 col5" >-4.700000</td>
#       <td id="T_25289_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_25289_row4_col7" class="data row4 col7" >0.000000</td>
#       <td id="T_25289_row4_col8" class="data row4 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25289_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_25289_row5_col0" class="data row5 col0" >504.500000</td>
#       <td id="T_25289_row5_col1" class="data row5 col1" >13.700000</td>
#       <td id="T_25289_row5_col2" class="data row5 col2" >57.000000</td>
#       <td id="T_25289_row5_col3" class="data row5 col3" >1.500000</td>
#       <td id="T_25289_row5_col4" class="data row5 col4" >1698.000000</td>
#       <td id="T_25289_row5_col5" class="data row5 col5" >5.100000</td>
#       <td id="T_25289_row5_col6" class="data row5 col6" >0.010000</td>
#       <td id="T_25289_row5_col7" class="data row5 col7" >0.000000</td>
#       <td id="T_25289_row5_col8" class="data row5 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_25289_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_25289_row6_col0" class="data row6 col0" >1065.250000</td>
#       <td id="T_25289_row6_col1" class="data row6 col1" >22.500000</td>
#       <td id="T_25289_row6_col2" class="data row6 col2" >74.000000</td>
#       <td id="T_25289_row6_col3" class="data row6 col3" >2.300000</td>
#       <td id="T_25289_row6_col4" class="dat

# %%
#Checking for unique values in all attribute
df.nunique().sort_values(ascending=True)
# Out:
# Holiday                     2
# Functioning Day             2
# Seasons                     4
# Hour                       24
# Snowfall                   51
# Rainfall                   61
# Wind speed                 65
# Humidity                   90
# Radiation                 345
# Date                      365
# Temperature(°C)           546
# Dew point temperature     556
# Visibility               1789
# Rented Bike Count        2166
# dtype: int64

# %%
#Checking for missing values in each column
df.isnull().sum()
# Out:
# Date                     0
# Rented Bike Count        0
# Hour                     0
# Temperature(°C)          0
# Humidity                 0
# Wind speed               0
# Visibility               0
# Dew point temperature    0
# Radiation                0
# Rainfall                 0
# Snowfall                 0
# Seasons                  0
# Holiday                  0
# Functioning Day          0
# dtype: int64

# %%
#Percentage of missing values in each column
pd.options.display.float_format = '{:,.2f} %'.format
print((df.isnull().sum()/len(df))*100)
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# Date                    0.00 %
# Rented Bike Count       0.00 %
# Hour                    0.00 %
# Temperature(°C)         0.00 %
# Humidity                0.00 %
# Wind speed              0.00 %
# Visibility              0.00 %
# Dew point temperature   0.00 %
# Radiation               0.00 %
# Rainfall                0.00 %
# Snowfall                0.00 %
# Seasons                 0.00 %
# Holiday                 0.00 %
# Functioning Day         0.00 %
# dtype: float64

# %%
#Missing Value Plot
import missingno as msno

# %%
msno.matrix(df,labels=[df.columns],figsize=(30,16),fontsize=12)
# Out:
# <AxesSubplot:>

# %%
#Bar plot
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(4,3, i+1)
    sns.barplot(data=df,x='Hour', y=col, ax=ax,edgecolor="black",palette='viridis_r')
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %%
#Checking the data distribution of each Continuous variable
plt.figure(figsize=(12, 12))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.histplot(data=df, x=col, ax=ax,color='red',kde=True)
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %%
#Box plot
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.boxplot(data=df, x=col, ax=ax,color='blue')
plt.suptitle('Box Plot of continuous variables')
plt.tight_layout()

# %%
#Power Transformation
#selecting variables that have data types float and int
var=list(df.select_dtypes(include=['float64','int64']).columns)

# %%
from sklearn.preprocessing import PowerTransformer
sc_X=PowerTransformer(method = 'yeo-johnson')
df[var]=sc_X.fit_transform(df[var])

# %%
#Data distribution after applying Power Transformer
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.histplot(data=df, x=col, ax=ax,color='red',kde=True)
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %%
#Box Plot after applying Power Transformer
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.boxplot(data=df, x=col, ax=ax,color='blue')
plt.suptitle('Box Plot of continuous variables')
plt.tight_layout()

# %%
#Heatmap
plt.figure(figsize=(8,8))
sns.heatmap(df.select_dtypes(include=['float']).corr(),annot=True,center=0)
plt.show()

# %%
#Analysing Categorical Variable
#Pie Chart
season_var=pd.crosstab(index=df['Seasons'],columns='% observations')
plt.pie(season_var['% observations'],labels=season_var['% observations'].index,autopct='%.0f%%')
plt.title('Seasons')
plt.show()

# %%
Functioning_Day_var=pd.crosstab(index=df['Functioning Day'],columns='% observations')
plt.pie(Functioning_Day_var['% observations'],labels=Functioning_Day_var['% observations'].index,autopct='%.0f%%')
plt.title('Functioning Day')
plt.show()

# %%
holiday_var=pd.crosstab(index=df['Holiday'],columns='% observations')
plt.pie(holiday_var['% observations'],labels=holiday_var['% observations'].index,autopct='%.0f%%')
plt.title('Holiday')
plt.show()

# %%
#Count plot shows that the Seasons variable is balanced
sns.barplot(x=season_var.index,y=season_var['% observations'])
plt.title('Seasons')
plt.show()

# %%
df=pd.get_dummies(df,columns=['Holiday','Seasons','Functioning Day','Hour'],drop_first=True)

# %%
X=df.iloc[:,2:]
y=df.iloc[:,1]

# %%
#Variance inflation Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    #Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(X.select_dtypes(include=['float','int']))
# Out:
#                variables   VIF
# 0        Temperature(°C) 45.79
# 1               Humidity 12.01
# 2             Wind speed  1.23
# 3             Visibility  1.56
# 4  Dew point temperature 60.27
# 5              Radiation  1.86
# 6               Rainfall  1.20
# 7               Snowfall  1.17

# %%
#Dew Point Temperature is highly correlated. let's delete this variable and check the VIF score again
del X['Dew point temperature']

# %%
calc_vif(X.select_dtypes(include=['float','int']))
#Each variable is within the range between 1 and 5.
# Out:
#          variables  VIF
# 0  Temperature(°C) 1.56
# 1         Humidity 2.44
# 2       Wind speed 1.23
# 3       Visibility 1.50
# 4        Radiation 1.83
# 5         Rainfall 1.19
# 6         Snowfall 1.16

# %%
#Feature Selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression #Correlation

# %%
fs = SelectKBest(score_func=f_regression, k='all')
fs.fit(X,y)
# Out:
# SelectKBest(k='all', score_func=<function f_regression at 0x16c2055e0>)

# %%
feature_contribution=(fs.scores_/sum(fs.scores_))*100

# %%
#Feature importance Graph
for i,j in enumerate(X.columns):
    print(f'{j} : {feature_contribution[i]:.2f}%')
plt.figure(figsize=(12,6))
sns.barplot(x=X.columns,y=fs.scores_)
plt.show()
# Out:
# Temperature(°C) : 24.19%
# Humidity : 3.52%
# Wind speed : 1.16%
# Visibility : 2.43%
# Radiation : 8.55%
# Rainfall : 5.65%
# Snowfall : 2.65%
# Holiday_No Holiday : 0.53%
# Seasons_Spring : 0.07%
# Seasons_Summer : 6.95%
# Seasons_Winter : 13.04%
# Functioning Day_Yes : 13.83%
# Hour_1 : 0.27%
# Hour_2 : 0.91%
# Hour_3 : 1.95%
# Hour_4 : 3.25%
# Hour_5 : 3.11%
# Hour_6 : 1.15%
# Hour_7 : 0.02%
# Hour_8 : 0.47%
# Hour_9 : 0.00%
# Hour_10 : 0.05%
# Hour_11 : 0.00%
# Hour_12 : 0.04%
# Hour_13 : 0.08%
# Hour_14 : 0.11%
# Hour_15 : 0.21%
# Hour_16 : 0.39%
# Hour_17 : 0.93%
# Hour_18 : 2.18%
# Hour_19 : 0.97%
# Hour_20 : 0.56%
# Hour_21 : 0.49%
# Hour_22 : 0.28%
# Hour_23 : 0.00%

# %%
#Splitting our dataset into train and test set
from sklearn.model_selection import train_test_split

# %%
#Splitting out dataset in 80% training and 20% testset
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
#Modeling
#K-fold Cross validation
#Importing differnet Regression models
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.model_selection import cross_val_score

# %%
#Creating dictionary for storing different models accuracy
model_comparison={}

# %%
#Linear Regression
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Linear Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 80.76%
# Model MSE : 19.16%
# Cross Val Accuracy: 80.35 %
# Cross Val Standard Deviation: 0.59 %

# %%
#import statsmodels.api as sm
lin_reg=sm.OLS(y_train,X_train).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Rented Bike Count   R-squared (uncentered):                   0.807
# Model:                            OLS   Adj. R-squared (uncentered):              0.805
# Method:                 Least Squares   F-statistic:                              726.5
# Date:                Thu, 17 Nov 2022   Prob (F-statistic):                        0.00
# Time:                        13:11:26   Log-Likelihood:                         -3668.0
# No. Observations:                6132   AIC:                                      7406.
# Df Residuals:                    6097   BIC:                                      7641.
# Df Model:                          35
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.3607      0.013     27.283      0.000       0.335       0.387
# x2            -0.1188      0.010    -12.492      0.000      -0.137      -0.100
# x3            -0.0206      0.007     -3.046      0.002      -0.034      -0.007
# x4             0.0084      0.007      1.157      0.247      -0.006       0.023
# x5             0.2291      0.017     13.603      0.000       0.196       0.262
# x6            -0.2603      0.006    -40.988      0.000      -0.273      -0.248
# x7            -0.0006      0.006     -0.102      0.919      -0.013       0.012
# x8             0.0513      0.006      8.986      0.000       0.040       0.063
# x9            -0.1030      0.007    -13.836      0.000      -0.118      -0.088
# x10           -0.0957      0.009    -10.381      0.000      -0.114      -0.078
# x11           -0.2716      0.010    -25.983      0.000      -0.292      -0.251
# x12            0.4646      0.006     79.193      0.000       0.453       0.476
# x13           -0.0427      0.008     -5.447      0.000      -0.058      -0.027
# x14           -0.0908      0.008    -11.508      0.000      -0.106      -0.075
# x15           -0.1212      0.008    -15.453      0.000      -0.137      -0.106
# x16           -0.1727      0.008    -22.168      0.000      -0.188      -0.157
# x17           -0.1624      0.008    -20.873      0.000      -0.178      -0.147
# x18           -0.0758      0.008     -9.681      0.000      -0.091      -0.060
# x19            0.0035      0.008      0.438      0.661      -0.012       0.019
# x20            0.0594      0.008      7.047      0.000       0.043       0.076
# x21           -0.0377      0.009     -4.072      0.000      -0.056      -0.020
# x22           -0.1138      0.010    -11.567      0.000      -0.133      -0.095
# x23           -0.1130      0.010    -11.231      0.000      -0.133      -0.093
# x24           -0.0958      0.010     -9.428      0.000      -0.116      -0.076
# x25           -0.1002      0.010     -9.764      0.000      -0.120      -0.080
# x26           -0.0995      0.010     -9.707      0.000      -0.120      -0.079
# x27           -0.0798      0.010     -7.930      0.000      -0.100      -0.060
# x28           -0.0477      0.010     -4.886      0.000      -0.067      -0.029
# x29            0.0128      0.009      1.391      0.164      -0.005       0.031
# x30            0.1193      0.008     14.495      0.000       0.103       0.135
# x31            0.0908      0.008     11.289      0.000       0.075       0.107
# x32            0.0832      0.008     10.710      0.000       0.068       0.098
# x33            0.0975      0.008     12.277      0.000       0.082       0.113
# x34            0.0698      0.008      8.942      0.000       0.055       0.085
# x35            0.0129      0.008      1.675      0.094      -0.002       0.028
# ==============================================================================
# Omnibus:                      409.821   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              872.074
# Skew:                          -0.445   Prob(JB):                    4.28e-190
# Kurtosis:                       4.619   Cond. No.                         9.45
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Assumptions of linear regression
residuals = lin_reg.resid
fitted_value = lin_reg.fittedvalues

# %%
np.mean(residuals)
# Out:
# 0.010699177021444278

# %%
#Checking for normality of the residuals
sm.qqplot(residuals,fit=True,line='45')
plt.title('Q-Q plot')
plt.show()

# %%
#Checking for homoscedasticity
plt.scatter(fitted_value, residuals)
plt.plot(y_train, [0]*len(y_train), c='r')
plt.title('Residuals Vs Fitted Plot')
plt.show()

# %%
#Polynomial Regression
poly_reg=PolynomialFeatures(degree=2)
model=LinearRegression()
model.fit(poly_reg.fit_transform(X_train),y_train)
y_pred=model.predict(poly_reg.fit_transform(X_test))
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Polynomial Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 88.65%
# Model MSE : 11.31%
# Cross Val Accuracy: 80.35 %
# Cross Val Standard Deviation: 0.59 %

# %%
#Decision Tree Regression
model=DecisionTreeRegressor()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Decision Tree Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 79.96%
# Model MSE : 19.97%
# Cross Val Accuracy: 79.44 %
# Cross Val Standard Deviation: 1.27 %

# %%
#Random Forest Regression
model=RandomForestRegressor(n_estimators=10,random_state=0)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Random forest Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 87.35%
# Model MSE : 12.60%
# Cross Val Accuracy: 88.23 %
# Cross Val Standard Deviation: 0.65 %

# %%
#Bagging Regressor
from sklearn.ensemble import BaggingRegressor
model= BaggingRegressor(RandomForestRegressor(n_estimators=10,random_state=0),random_state=0)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Bagging Regressor']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 88.42%
# Model MSE : 11.53%
# Cross Val Accuracy: 89.08 %
# Cross Val Standard Deviation: 0.66 %

# %%
#Stacking Regressor
estimators=[('linear regression',LinearRegression()),('Decision Tree',DecisionTreeRegressor()),('random forest',RandomForestRegressor(n_estimators=10,random_state=0)),('bagging',BaggingRegressor(RandomForestRegressor(n_estimators=10,random_state=0),random_state=0))]

# %%
model=StackingRegressor(estimators=estimators,final_estimator=LinearRegression(),passthrough=True)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Stacking Regressor']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 89.05%
# Model MSE : 10.91%
# Cross Val Accuracy: 89.74 %
# Cross Val Standard Deviation: 0.57 %

# %%
#Model Comparison
Model_com_df=pd.DataFrame(model_comparison).T
Model_com_df.columns=['R-Square','MSE','CV Accuracy','CV std']
Model_com_df=Model_com_df.sort_values(by='R-Square',ascending=False)
Model_com_df.style.format("{:.2%}").background_gradient(cmap='RdYlBu_r')
# Out:
# <style type="text/css">
# #T_d4262_row0_col0, #T_d4262_row0_col2, #T_d4262_row5_col1, #T_d4262_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d4262_row0_col1, #T_d4262_row0_col3, #T_d4262_row5_col0, #T_d4262_row5_col2 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_d4262_row1_col0 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_d4262_row1_col1 {
#   background-color: #3a51a2;
#   color: #f1f1f1;
# }
# #T_d4262_row1_col2, #T_d4262_row4_col0, #T_d4262_row4_col2 {
#   background-color: #426cb0;
#   color: #f1f1f1;
# }
# #T_d4262_row1_col3, #T_d4262_row4_col3 {
#   background-color: #36479e;
#   color: #f1f1f1;
# }
# #T_d4262_row2_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_d4262_row2_col1 {
#   background-color: #3e60aa;
#   color: #f1f1f1;
# }
# #T_d4262_row2_col2 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_d4262_row2_col3 {
#   background-color: #4d7fb9;
#   color: #f1f1f1;
# }
# #T_d4262_row3_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_d4262_row3_col1 {
#   background-color: #6da4cc;
#   color: #f1f1f1;
# }
# #T_d4262_row3_col2 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_d4262_row3_col3 {
#   background-color: #4b7db8;
#   color: #f1f1f1;
# }
# #T_d4262_row4_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d4262">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4262_level0_col0" class="col_heading level0 col0" >R-Square</th>
#       <th id="T_d4262_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d4262_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_d4262_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4262_level0_row0" class="row_heading level0 row0" >Stacking Regressor</th>
#       <td id="T_d4262_row0_col0" class="data row0 col0" >89.05%</td>
#       <td id="T_d4262_row0_col1" class="data row0 col1" >10.91%</td>
#       <td id="T_d4262_row0_col2" class="data row0 col2" >89.74%</td>
#       <td id="T_d4262_row0_col3" class="data row0 col3" >0.57%</td>
#     </tr>
#     <tr>
#       <th id="T_d4262_level0_row1" class="row_heading level0 row1" >Polynomial Regression</th>
#       <td id="T_d4262_row1_col0" class="data row1 col0" >88.65%</td>
#       <td id="T_d4262_row1_col1" class="data row1 col1" >11.31%</td>
#       <td id="T_d4262_row1_col2" class="data row1 col2" >80.35%</td>
#       <td id="T_d4262_row1_col3" class="data row1 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_d4262_level0_row2" class="row_heading level0 row2" >Bagging Regressor</th>
#       <td id="T_d4262_row2_col0" class="data row2 col0" >88.42%</td>
#       <td id="T_d4262_row2_col1" class="data row2 col1" >11.53%</td>
#       <td id="T_d4262_row2_col2" class="data row2 col2" >89.08%</td>
#       <td id="T_d4262_row2_col3" class="data row2 col3" >0.66%</td>
#     </tr>
#     <tr>
#       <th id="T_d4262_level0_row3" class="row_heading level0 row3" >Random forest Regression</th>
#       <td id="T_d4262_row3_col0" class="data row3 col0" >87.35%</td>
#       <td id="T_d4262_row3_col1" class="data row3 col1" >12.60%</td>
#       <td id="T_d4262_row3_col2" class="data row3 col2" >88.23%</td>
#       <td id="T_d4262_row3_col3" class="data row3 col3" >0.65%</td>
#     </tr>
#     <tr>
#       <th id="T_d4262_level0_row4" class="row_heading level0 row4" >Linear Regression</th>
#       <td id="T_d4262_row4_col0" class="data row4 col0" >80.76%</td>
#       <td id="T_d4262_row4_col1" class="data row4 col1" >19.16%</td>
#       <td id="T_d4262_row4_col2" class="data row4 col2" >80.35%</td>
#       <td id="T_d4262_row4_col3" class="data row4 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_d4262_level0_row5" class="row_heading level0 row5" >Decision Tree Regression</th>
#       <td id="T_d4262_row5_col0" class="data row5 col0" >79.96%</td>
#       <td id="T_d4262_row5_col1" class="data row5 col1" >19.97%</td>
#       <td id="T_d4262_row5_col2" class="data row5 col2" >79.44%</td>
#       <td id="T_d4262_row5_col3" class="data row5 col3" >1.27%</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Maximum Accuracies in each Column
Model_com_df.style.highlight_max().set_caption("Maximum Score in each Column").format("{:.2%}")
# Out:
# <style type="text/css">
# #T_9c402_row0_col0, #T_9c402_row0_col2, #T_9c402_row5_col1, #T_9c402_row5_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9c402">
#   <caption>Maximum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c402_level0_col0" class="col_heading level0 col0" >R-Square</th>
#       <th id="T_9c402_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9c402_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_9c402_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c402_level0_row0" class="row_heading level0 row0" >Stacking Regressor</th>
#       <td id="T_9c402_row0_col0" class="data row0 col0" >89.05%</td>
#       <td id="T_9c402_row0_col1" class="data row0 col1" >10.91%</td>
#       <td id="T_9c402_row0_col2" class="data row0 col2" >89.74%</td>
#       <td id="T_9c402_row0_col3" class="data row0 col3" >0.57%</td>
#     </tr>
#     <tr>
#       <th id="T_9c402_level0_row1" class="row_heading level0 row1" >Polynomial Regression</th>
#       <td id="T_9c402_row1_col0" class="data row1 col0" >88.65%</td>
#       <td id="T_9c402_row1_col1" class="data row1 col1" >11.31%</td>
#       <td id="T_9c402_row1_col2" class="data row1 col2" >80.35%</td>
#       <td id="T_9c402_row1_col3" class="data row1 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_9c402_level0_row2" class="row_heading level0 row2" >Bagging Regressor</th>
#       <td id="T_9c402_row2_col0" class="data row2 col0" >88.42%</td>
#       <td id="T_9c402_row2_col1" class="data row2 col1" >11.53%</td>
#       <td id="T_9c402_row2_col2" class="data row2 col2" >89.08%</td>
#       <td id="T_9c402_row2_col3" class="data row2 col3" >0.66%</td>
#     </tr>
#     <tr>
#       <th id="T_9c402_level0_row3" class="row_heading level0 row3" >Random forest Regression</th>
#       <td id="T_9c402_row3_col0" class="data row3 col0" >87.35%</td>
#       <td id="T_9c402_row3_col1" class="data row3 col1" >12.60%</td>
#       <td id="T_9c402_row3_col2" class="data row3 col2" >88.23%</td>
#       <td id="T_9c402_row3_col3" class="data row3 col3" >0.65%</td>
#     </tr>
#     <tr>
#       <th id="T_9c402_level0_row4" class="row_heading level0 row4" >Linear Regression</th>
#       <td id="T_9c402_row4_col0" class="data row4 col0" >80.76%</td>
#       <td id="T_9c402_row4_col1" class="data row4 col1" >19.16%</td>
#       <td id="T_9c402_row4_col2" class="data row4 col2" >80.35%</td>
#       <td id="T_9c402_row4_col3" class="data row4 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_9c402_level0_row5" class="row_heading level0 row5" >Decision Tree Regression</th>
#       <td id="T_9c402_row5_col0" class="data row5 col0" >79.96%</td>
#       <td id="T_9c402_row5_col1" class="data row5 col1" >19.97%</td>
#       <td id="T_9c402_row5_col2" class="data row5 col2" >79.44%</td>
#       <td id="T_9c402_row5_col3" class="data row5 col3" >1.27%</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Minimum Accuracies in each Column
Model_com_df.style.highlight_min().set_caption("Minimum Score in each Column").format("{:.2%}")
# Out:
# <style type="text/css">
# #T_f917d_row0_col1, #T_f917d_row0_col3, #T_f917d_row5_col0, #T_f917d_row5_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f917d">
#   <caption>Minimum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f917d_level0_col0" class="col_heading level0 col0" >R-Square</th>
#       <th id="T_f917d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f917d_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_f917d_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f917d_level0_row0" class="row_heading level0 row0" >Stacking Regressor</th>
#       <td id="T_f917d_row0_col0" class="data row0 col0" >89.05%</td>
#       <td id="T_f917d_row0_col1" class="data row0 col1" >10.91%</td>
#       <td id="T_f917d_row0_col2" class="data row0 col2" >89.74%</td>
#       <td id="T_f917d_row0_col3" class="data row0 col3" >0.57%</td>
#     </tr>
#     <tr>
#       <th id="T_f917d_level0_row1" class="row_heading level0 row1" >Polynomial Regression</th>
#       <td id="T_f917d_row1_col0" class="data row1 col0" >88.65%</td>
#       <td id="T_f917d_row1_col1" class="data row1 col1" >11.31%</td>
#       <td id="T_f917d_row1_col2" class="data row1 col2" >80.35%</td>
#       <td id="T_f917d_row1_col3" class="data row1 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_f917d_level0_row2" class="row_heading level0 row2" >Bagging Regressor</th>
#       <td id="T_f917d_row2_col0" class="data row2 col0" >88.42%</td>
#       <td id="T_f917d_row2_col1" class="data row2 col1" >11.53%</td>
#       <td id="T_f917d_row2_col2" class="data row2 col2" >89.08%</td>
#       <td id="T_f917d_row2_col3" class="data row2 col3" >0.66%</td>
#     </tr>
#     <tr>
#       <th id="T_f917d_level0_row3" class="row_heading level0 row3" >Random forest Regression</th>
#       <td id="T_f917d_row3_col0" class="data row3 col0" >87.35%</td>
#       <td id="T_f917d_row3_col1" class="data row3 col1" >12.60%</td>
#       <td id="T_f917d_row3_col2" class="data row3 col2" >88.23%</td>
#       <td id="T_f917d_row3_col3" class="data row3 col3" >0.65%</td>
#     </tr>
#     <tr>
#       <th id="T_f917d_level0_row4" class="row_heading level0 row4" >Linear Regression</th>
#       <td id="T_f917d_row4_col0" class="data row4 col0" >80.76%</td>
#       <td id="T_f917d_row4_col1" class="data row4 col1" >19.16%</td>
#       <td id="T_f917d_row4_col2" class="data row4 col2" >80.35%</td>
#       <td id="T_f917d_row4_col3" class="data row4 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_f917d_level0_row5" class="row_heading level0 row5" >Decision Tree Regression</th>
#       <td id="T_f917d_row5_col0" class="data row5 col0" >79.96%</td>
#       <td id="T_f917d_row5_col1" class="data row5 col1" >19.97%</td>
#       <td id="T_f917d_row5_col2" class="data row5 col2" >79.44%</td>
#       <td id="T_f917d_row5_col3" class="data row5 col3" >1.27%</td>
#     </tr>
#   </tbody>
# </table>
